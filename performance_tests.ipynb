# %% [markdown]
# Execution query(process) without index

# %%
import query_no_index

query_no_index.process()
# Out:
# Execution time: 0:00:02.225147

# %% [markdown]
# Execution query(process) with index

# %%
import create_index

create_index.claim()
query_no_index.process()
# Out:
# Index has been successfully created
# Execution time: 0:00:01.799290
